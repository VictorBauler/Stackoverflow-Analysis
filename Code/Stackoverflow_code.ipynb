# %% [markdown]
# # Business questions
#
# 1. What is the favorite programming language by data scientists on each year?
# 2. What is the most used database environment by data scientists on each year?
# 3. What are the top 3 features to predict an data scientist salary on 2021?
